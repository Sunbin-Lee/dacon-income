# %%
import pandas as pd
import numpy as np

# %%
xgb = pd.read_csv('xgb.csv', header = None)
# xgb.drop_duplicates(inplace=True)

# %%
xgb
# Out:
#                                      0       1       2       3       4  \
# 0       train_n_100_lr_0.3_d_3_child_1  438.95  438.61  444.65  436.71
# 1         val_n_100_lr_0.3_d_3_child_1  465.61  472.75  447.77  478.95
# 2       train_n_100_lr_0.3_d_3_child_2  439.90  438.32  444.60  436.83
# 3         val_n_100_lr_0.3_d_3_child_2  464.40  472.18  448.26  479.38
# 4       train_n_100_lr_0.3_d_3_child_5  440.25  440.50  444.57  436.06
# ..                                 ...     ...     ...     ...     ...
# 507     val_n_1000_lr_0.05_d_6_child_2  478.42  488.06  460.98  489.48
# 508   train_n_1000_lr_0.05_d_6_child_5  336.39  338.15  342.96  337.15
# 509     val_n_1000_lr_0.05_d_6_child_5  476.48  483.32  462.18  489.46
# 510  train_n_1000_lr_0.05_d_6_child_10  356.01  359.67  357.82  351.31
# 511    val_n_1000_lr_0.05_d_6_child_10  476.59  482.65  457.02  488.02
#
#           5       6
# 0    440.97  439.98
# 1    456.21  464.26
# 2    440.92  440.11
# 3    454.27  463.70
# ...

# %%
df = xgb

# %%
df[6] = np.round((df[1] + df[2] + df[3] + df[4] + df[5])/5, 2)

# %%
df.to_csv('xgb_mod.csv', header=False, index=False)
